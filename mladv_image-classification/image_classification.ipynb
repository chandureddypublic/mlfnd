# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    mx = x.max()
    g = np.vectorize(lambda x: x / mx)
    return g(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    y = np.zeros((len(x), 10))
    rows = range(len(x))
    cols = list(x)
    y[rows, cols] = 1
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    shape = [None]
    shape.extend(image_shape)
    return tf.placeholder(tf.float32, shape=shape, name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None), name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
from math import sqrt

def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # Cretae Weights and Biases
    w_shape = [conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3], conv_num_outputs]
    stddev = sqrt(2/(conv_ksize[0] * conv_ksize[1] * x_tensor.get_shape().as_list()[3]))
    weights = tf.Variable(tf.truncated_normal(w_shape, stddev=stddev))
    biases = tf.Variable(tf.zeros([conv_num_outputs]))
    # Apply Convolution by appying same padding
    convolution = tf.nn.conv2d(x_tensor, weights, [1,conv_strides[0],conv_strides[1],1], padding="SAME")
    # Add bias
    convolution = tf.nn.bias_add(convolution, biases)
    relu = tf.nn.relu(convolution)
    # Max pooling
    k_size = [1, pool_ksize[0], pool_ksize[1],1]
    m_strides = [1, pool_strides[0], pool_strides[1],1]
    max_pool = tf.nn.max_pool(relu, ksize=k_size, strides=m_strides, padding="SAME")

    return max_pool


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()[1:]
    dim_flatt = shape[0]*shape[1]*shape[2]
    
    flatx = tf.reshape(x_tensor, [-1, dim_flatt])
    return flatx


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w_shape = [x_tensor.get_shape().as_list()[1], num_outputs]
    stddev = sqrt(2/x_tensor.get_shape().as_list()[1])
    
    weights = tf.Variable(tf.truncated_normal(w_shape, stddev=stddev))
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.nn.relu(tf.add(tf.matmul(x_tensor, weights), biases))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w_shape = [x_tensor.get_shape().as_list()[1], num_outputs]
    stddev = sqrt(2/x_tensor.get_shape().as_list()[1])
    
    weights = tf.Variable(tf.truncated_normal(w_shape, stddev=stddev))   
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.add(tf.matmul(x_tensor, weights), biases)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_dropout_prob = keep_prob / 2
    conv1 = conv2d_maxpool(x, 48, (3, 3), (1, 1), (2, 2), (2, 2))
    conv2 = conv2d_maxpool(conv1, 96, (3, 3), (1, 1), (2, 2), (2, 2))
    conv3 = conv2d_maxpool(conv2, 192, (3, 3), (1, 1), (2, 2), (2, 2))    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv3)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fconn = fully_conn(flat, 1024) 
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    fconn = fully_conn(fconn_w_dropout, 512)
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    fconn = fully_conn(fconn_w_dropout, 256)
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    result = output(fconn_w_dropout, 10)   
    
    # TODO: return output
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.}
    loss = session.run(cost, feed_dict)
    feed_dict={x: valid_features,y: valid_labels,keep_prob: 1.}
    valid_acc = sess.run(accuracy, feed_dict)

    print('Epoch Loss:{:>6.4f} Validation Accuracy:{:.6f}'.format(loss,valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 64
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch-{:>2},CIFAR-10 Batch-{}:  '.format(epoch+1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch- 1,CIFAR-10 Batch-1:  Epoch Loss:1.9443 Validation Accuracy:0.323800
# Epoch- 2,CIFAR-10 Batch-1:  Epoch Loss:1.6897 Validation Accuracy:0.435200
# Epoch- 3,CIFAR-10 Batch-1:  Epoch Loss:1.4958 Validation Accuracy:0.470800
# Epoch- 4,CIFAR-10 Batch-1:  Epoch Loss:1.2831 Validation Accuracy:0.512600
# Epoch- 5,CIFAR-10 Batch-1:  Epoch Loss:1.0599 Validation Accuracy:0.530200
# Epoch- 6,CIFAR-10 Batch-1:  Epoch Loss:1.0672 Validation Accuracy:0.565400
# Epoch- 7,CIFAR-10 Batch-1:  Epoch Loss:0.9706 Validation Accuracy:0.569200
# Epoch- 8,CIFAR-10 Batch-1:  Epoch Loss:0.7163 Validation Accuracy:0.588000
# Epoch- 9,CIFAR-10 Batch-1:  Epoch Loss:0.5097 Validation Accuracy:0.585800
# Epoch-10,CIFAR-10 Batch-1:  Epoch Loss:0.3773 Validation Accuracy:0.592400
# Epoch-11,CIFAR-10 Batch-1:  Epoch Loss:0.2636 Validation Accuracy:0.596200
# Epoch-12,CIFAR-10 Batch-1:  Epoch Loss:0.1540 Validation Accuracy:0.589400
# Epoch-13,CIFAR-10 Batch-1:  Epoch Loss:0.0879 Validation Accuracy:0.586200
# Epoch-14,CIFAR-10 Batch-1:  Epoch Loss:0.1003 Validation Accuracy:0.583000
# Epoch-15,CIFAR-10 Batch-1:  Epoch Loss:0.0425 Validation Accuracy:0.590600
# Epoch-16,CIFAR-10 Batch-1:  Epoch Loss:0.0776 Validation Accuracy:0.593600
# Epoch-17,CIFAR-10 Batch-1:  Epoch Loss:0.0238 Validation Accuracy:0.595000
# Epoch-18,CIFAR-10 Batch-1:  Epoch Loss:0.0220 Validation Accuracy:0.595600
# Epoch-19,CIFAR-10 Batch-1:  Epoch Loss:0.0102 Validation Accuracy:0.584600
# Epoch-20,CIFAR-10 Batch-1:  Epoch Loss:0.0069 Validation Accuracy:0.588400
# Epoch-21,CIFAR-10 Batch-1:  Epoch Loss:0.0102 Validation Accuracy:0.584400
# Epoch-22,CIFAR-10 Batch-1:  Epoch Loss:0.0072 Validation Accuracy:0.585600
# Epoch-23,CIFAR-10 Batch-1:  Epoch Loss:0.0063 Validation Accuracy:0.598800
# Epoch-24,CIFAR-10 Batch-1:  Epoch Loss:0.0040 Validation Accuracy:0.594200
# Epoch-25,CIFAR-10 Batch-1:  Epoch Loss:0.0019 Validation Accuracy:0.590000
# Epoch-26,CIFAR-10 Batch-1:  Epoch Loss:0.0040 Validation Accuracy:0.602600
# Epoch-27,CIFAR-10 Batch-1:  Epoch Loss:0.0019 Validation Accuracy:0.599800
# Epoch-28,CIFAR-10 Batch-1:  Epoch Loss:0.0076 Validation Accuracy:0.592800
# Epoch-29,CIFAR-10 Batch-1:  Epoch Loss:0.0012 Validation Accuracy:0.593000
# Epoch-30,CIFAR-10 Batch-1:  Epoch Loss:0.0026 Validation Accuracy:0.594000
# Epoch-31,CIFAR-10 Batch-1:  Epoch Loss:0.0021 Validation Accuracy:0.599600
# Epoch-32,CIFAR-10 Batch-1:  Epoch Loss:0.0021 Validation Accuracy:0.603200
# Epoch-33,CIFAR-10 Batch-1:  Epoch Loss:0.0008 Validation Accuracy:0.589000
# Epoch-34,CIFAR-10 Batch-1:  Epoch Loss:0.0009 Validation Accuracy:0.591400
# Epoch-35,CIFAR-10 Batch-1:  Epoch Loss:0.0020 Validation Accuracy:0.602600
# Epoch-36,CIFAR-10 Batch-1:  Epoch Loss:0.0011 Validation Accuracy:0.601400
# Epoch-37,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.618400
# Epoch-38,CIFAR-10 Batch-1:  Epoch Loss:0.0010 Validation Accuracy:0.603200
# Epoch-39,CIFAR-10 Batch-1:  Epoch Loss:0.0008 Validation Accuracy:0.607400
# Epoch-40,CIFAR-10 Batch-1:  Epoch Loss:0.0200 Validation Accuracy:0.607400
# Epoch-41,CIFAR-10 Batch-1:  Epoch Loss:0.0005 Validation Accuracy:0.589000
# Epoch-42,CIFAR-10 Batch-1:  Epoch Loss:0.0063 Validation Accuracy:0.598400
# Epoch-43,CIFAR-10 Batch-1:  Epoch Loss:0.0020 Validation Accuracy:0.610200
# Epoch-44,CIFAR-10 Batch-1:  Epoch Loss:0.0163 Validation Accuracy:0.575200
# Epoch-45,CIFAR-10 Batch-1:  Epoch Loss:0.0027 Validation Accuracy:0.612400
# Epoch-46,CIFAR-10 Batch-1:  Epoch Loss:0.0075 Validation Accuracy:0.598800
# Epoch-47,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.604200
# Epoch-48,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.596200
# Epoch-49,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.608600
# Epoch-50,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.605600
# Epoch-51,CIFAR-10 Batch-1:  Epoch Loss:0.0017 Validation Accuracy:0.599200
# Epoch-52,CIFAR-10 Batch-1:  Epoch Loss:0.0003 Validation Accuracy:0.597000
# Epoch-53,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.600200
# Epoch-54,CIFAR-10 Batch-1:  Epoch Loss:0.0003 Validation Accuracy:0.599600
# Epoch-55,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.612000
# Epoch-56,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.583000
# Epoch-57,CIFAR-10 Batch-1:  Epoch Loss:0.0074 Validation Accuracy:0.609000
# Epoch-58,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.595800
# Epoch-59,CIFAR-10 Batch-1:  Epoch Loss:0.0008 Validation Accuracy:0.609000
# Epoch-60,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.607200
# Epoch-61,CIFAR-10 Batch-1:  Epoch Loss:0.0337 Validation Accuracy:0.608800
# Epoch-62,CIFAR-10 Batch-1:  Epoch Loss:0.0016 Validation Accuracy:0.610000
# Epoch-63,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.587400
# Epoch-64,CIFAR-10 Batch-1:  Epoch Loss:0.0270 Validation Accuracy:0.600800
# Epoch-65,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.602600
# Epoch-66,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.624800
# Epoch-67,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.614800
# Epoch-68,CIFAR-10 Batch-1:  Epoch Loss:0.0014 Validation Accuracy:0.602800
# Epoch-69,CIFAR-10 Batch-1:  Epoch Loss:0.0003 Validation Accuracy:0.613600
# Epoch-70,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.624600
# Epoch-71,CIFAR-10 Batch-1:  Epoch Loss:0.0014 Validation Accuracy:0.607000
# Epoch-72,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.617400
# Epoch-73,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.605000
# Epoch-74,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.618800
# Epoch-75,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.610800
# Epoch-76,CIFAR-10 Batch-1:  Epoch Loss:0.0018 Validation Accuracy:0.592800
# Epoch-77,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.610200
# Epoch-78,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.613000
# Epoch-79,CIFAR-10 Batch-1:  Epoch Loss:0.0017 Validation Accuracy:0.612800
# Epoch-80,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.615000
# Epoch-81,CIFAR-10 Batch-1:  Epoch Loss:0.0058 Validation Accuracy:0.608200
# Epoch-82,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.602400
# Epoch-83,CIFAR-10 Batch-1:  Epoch Loss:0.0005 Validation Accuracy:0.600400
# Epoch-84,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.610200
# Epoch-85,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.614800
# Epoch-86,CIFAR-10 Batch-1:  Epoch Loss:0.0028 Validation Accuracy:0.580600
# Epoch-87,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.613200
# Epoch-88,CIFAR-10 Batch-1:  Epoch Loss:0.0027 Validation Accuracy:0.610000
# Epoch-89,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.612400
# Epoch-90,CIFAR-10 Batch-1:  Epoch Loss:0.0035 Validation Accuracy:0.595600
# Epoch-91,CIFAR-10 Batch-1:  Epoch Loss:0.0003 Validation Accuracy:0.605600
# Epoch-92,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.613200
# Epoch-93,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.606200
# Epoch-94,CIFAR-10 Batch-1:  Epoch Loss:0.0009 Validation Accuracy:0.620200
# Epoch-95,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.601800
# Epoch-96,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.604200
# Epoch-97,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.603800
# Epoch-98,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.611200
# Epoch-99,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.617400
# Epoch-100,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.604400

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch-{:>2},CIFAR-10 Batch-{}:  '.format(epoch+1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch- 1,CIFAR-10 Batch-1:  Epoch Loss:1.9756 Validation Accuracy:0.327400
# Epoch- 1,CIFAR-10 Batch-2:  Epoch Loss:1.5206 Validation Accuracy:0.440600
# Epoch- 1,CIFAR-10 Batch-3:  Epoch Loss:1.2818 Validation Accuracy:0.489800
# Epoch- 1,CIFAR-10 Batch-4:  Epoch Loss:1.2555 Validation Accuracy:0.531600
# Epoch- 1,CIFAR-10 Batch-5:  Epoch Loss:1.2147 Validation Accuracy:0.571200
# Epoch- 2,CIFAR-10 Batch-1:  Epoch Loss:1.1224 Validation Accuracy:0.584800
# Epoch- 2,CIFAR-10 Batch-2:  Epoch Loss:0.9243 Validation Accuracy:0.602200
# Epoch- 2,CIFAR-10 Batch-3:  Epoch Loss:0.7911 Validation Accuracy:0.634200
# Epoch- 2,CIFAR-10 Batch-4:  Epoch Loss:0.7377 Validation Accuracy:0.636000
# Epoch- 2,CIFAR-10 Batch-5:  Epoch Loss:0.9171 Validation Accuracy:0.650000
# Epoch- 3,CIFAR-10 Batch-1:  Epoch Loss:0.8548 Validation Accuracy:0.657400
# Epoch- 3,CIFAR-10 Batch-2:  Epoch Loss:0.7285 Validation Accuracy:0.660200
# Epoch- 3,CIFAR-10 Batch-3:  Epoch Loss:0.6682 Validation Accuracy:0.667000
# Epoch- 3,CIFAR-10 Batch-4:  Epoch Loss:0.6650 Validation Accuracy:0.668200
# Epoch- 3,CIFAR-10 Batch-5:  Epoch Loss:0.6409 Validation Accuracy:0.674000
# Epoch- 4,CIFAR-10 Batch-1:  Epoch Loss:0.8199 Validation Accuracy:0.676000
# Epoch- 4,CIFAR-10 Batch-2:  Epoch Loss:0.6111 Validation Accuracy:0.683000
# Epoch- 4,CIFAR-10 Batch-3:  Epoch Loss:0.4676 Validation Accuracy:0.672600
# Epoch- 4,CIFAR-10 Batch-4:  Epoch Loss:0.4425 Validation Accuracy:0.700800
# Epoch- 4,CIFAR-10 Batch-5:  Epoch Loss:0.4523 Validation Accuracy:0.689200
# Epoch- 5,CIFAR-10 Batch-1:  Epoch Loss:0.6444 Validation Accuracy:0.679200
# Epoch- 5,CIFAR-10 Batch-2:  Epoch Loss:0.5000 Validation Accuracy:0.696600
# Epoch- 5,CIFAR-10 Batch-3:  Epoch Loss:0.3012 Validation Accuracy:0.667800
# Epoch- 5,CIFAR-10 Batch-4:  Epoch Loss:0.3025 Validation Accuracy:0.699200
# Epoch- 5,CIFAR-10 Batch-5:  Epoch Loss:0.3279 Validation Accuracy:0.701000
# Epoch- 6,CIFAR-10 Batch-1:  Epoch Loss:0.5188 Validation Accuracy:0.692000
# Epoch- 6,CIFAR-10 Batch-2:  Epoch Loss:0.3395 Validation Accuracy:0.719000
# Epoch- 6,CIFAR-10 Batch-3:  Epoch Loss:0.2118 Validation Accuracy:0.692600
# Epoch- 6,CIFAR-10 Batch-4:  Epoch Loss:0.2121 Validation Accuracy:0.708200
# Epoch- 6,CIFAR-10 Batch-5:  Epoch Loss:0.2780 Validation Accuracy:0.701200
# Epoch- 7,CIFAR-10 Batch-1:  Epoch Loss:0.4313 Validation Accuracy:0.721800
# Epoch- 7,CIFAR-10 Batch-2:  Epoch Loss:0.2163 Validation Accuracy:0.716600
# Epoch- 7,CIFAR-10 Batch-3:  Epoch Loss:0.1547 Validation Accuracy:0.699600
# Epoch- 7,CIFAR-10 Batch-4:  Epoch Loss:0.2076 Validation Accuracy:0.712800
# Epoch- 7,CIFAR-10 Batch-5:  Epoch Loss:0.2154 Validation Accuracy:0.725600
# Epoch- 8,CIFAR-10 Batch-1:  Epoch Loss:0.3526 Validation Accuracy:0.728200
# Epoch- 8,CIFAR-10 Batch-2:  Epoch Loss:0.2042 Validation Accuracy:0.707000
# Epoch- 8,CIFAR-10 Batch-3:  Epoch Loss:0.1395 Validation Accuracy:0.720400
# Epoch- 8,CIFAR-10 Batch-4:  Epoch Loss:0.1547 Validation Accuracy:0.717600
# Epoch- 8,CIFAR-10 Batch-5:  Epoch Loss:0.1176 Validation Accuracy:0.724200
# Epoch- 9,CIFAR-10 Batch-1:  Epoch Loss:0.2654 Validation Accuracy:0.721600
# Epoch- 9,CIFAR-10 Batch-2:  Epoch Loss:0.1731 Validation Accuracy:0.714400
# Epoch- 9,CIFAR-10 Batch-3:  Epoch Loss:0.0682 Validation Accuracy:0.715600
# Epoch- 9,CIFAR-10 Batch-4:  Epoch Loss:0.0927 Validation Accuracy:0.720000
# Epoch- 9,CIFAR-10 Batch-5:  Epoch Loss:0.1442 Validation Accuracy:0.720400
# Epoch-10,CIFAR-10 Batch-1:  Epoch Loss:0.2484 Validation Accuracy:0.731000
# Epoch-10,CIFAR-10 Batch-2:  Epoch Loss:0.1600 Validation Accuracy:0.716000
# Epoch-10,CIFAR-10 Batch-3:  Epoch Loss:0.1259 Validation Accuracy:0.719200
# Epoch-10,CIFAR-10 Batch-4:  Epoch Loss:0.1250 Validation Accuracy:0.720200
# Epoch-10,CIFAR-10 Batch-5:  Epoch Loss:0.0797 Validation Accuracy:0.725600
# Epoch-11,CIFAR-10 Batch-1:  Epoch Loss:0.1322 Validation Accuracy:0.730400
# Epoch-11,CIFAR-10 Batch-2:  Epoch Loss:0.0765 Validation Accuracy:0.714400
# Epoch-11,CIFAR-10 Batch-3:  Epoch Loss:0.1222 Validation Accuracy:0.710200
# Epoch-11,CIFAR-10 Batch-4:  Epoch Loss:0.1057 Validation Accuracy:0.728400
# Epoch-11,CIFAR-10 Batch-5:  Epoch Loss:0.0453 Validation Accuracy:0.733400
# Epoch-12,CIFAR-10 Batch-1:  Epoch Loss:0.1227 Validation Accuracy:0.718800
# Epoch-12,CIFAR-10 Batch-2:  Epoch Loss:0.0894 Validation Accuracy:0.717200
# Epoch-12,CIFAR-10 Batch-3:  Epoch Loss:0.0363 Validation Accuracy:0.725800
# Epoch-12,CIFAR-10 Batch-4:  Epoch Loss:0.0383 Validation Accuracy:0.714800
# Epoch-12,CIFAR-10 Batch-5:  Epoch Loss:0.0193 Validation Accuracy:0.729200
# Epoch-13,CIFAR-10 Batch-1:  Epoch Loss:0.1356 Validation Accuracy:0.714600
# Epoch-13,CIFAR-10 Batch-2:  Epoch Loss:0.0565 Validation Accuracy:0.728400
# Epoch-13,CIFAR-10 Batch-3:  Epoch Loss:0.0226 Validation Accuracy:0.727000
# Epoch-13,CIFAR-10 Batch-4:  Epoch Loss:0.0455 Validation Accuracy:0.727800
# Epoch-13,CIFAR-10 Batch-5:  Epoch Loss:0.0151 Validation Accuracy:0.726400
# Epoch-14,CIFAR-10 Batch-1:  Epoch Loss:0.0504 Validation Accuracy:0.715600
# Epoch-14,CIFAR-10 Batch-2:  Epoch Loss:0.0132 Validation Accuracy:0.734600
# Epoch-14,CIFAR-10 Batch-3:  Epoch Loss:0.0105 Validation Accuracy:0.736000
# Epoch-14,CIFAR-10 Batch-4:  Epoch Loss:0.0602 Validation Accuracy:0.719600
# Epoch-14,CIFAR-10 Batch-5:  Epoch Loss:0.0084 Validation Accuracy:0.722600
# Epoch-15,CIFAR-10 Batch-1:  Epoch Loss:0.0244 Validation Accuracy:0.719200
# Epoch-15,CIFAR-10 Batch-2:  Epoch Loss:0.0217 Validation Accuracy:0.730600
# Epoch-15,CIFAR-10 Batch-3:  Epoch Loss:0.0298 Validation Accuracy:0.722400
# Epoch-15,CIFAR-10 Batch-4:  Epoch Loss:0.0850 Validation Accuracy:0.727400
# Epoch-15,CIFAR-10 Batch-5:  Epoch Loss:0.0378 Validation Accuracy:0.725800
# Epoch-16,CIFAR-10 Batch-1:  Epoch Loss:0.0362 Validation Accuracy:0.738000
# Epoch-16,CIFAR-10 Batch-2:  Epoch Loss:0.0116 Validation Accuracy:0.736200
# Epoch-16,CIFAR-10 Batch-3:  Epoch Loss:0.0086 Validation Accuracy:0.731000
# Epoch-16,CIFAR-10 Batch-4:  Epoch Loss:0.0086 Validation Accuracy:0.731800
# Epoch-16,CIFAR-10 Batch-5:  Epoch Loss:0.0104 Validation Accuracy:0.728200
# Epoch-17,CIFAR-10 Batch-1:  Epoch Loss:0.0291 Validation Accuracy:0.733200
# Epoch-17,CIFAR-10 Batch-2:  Epoch Loss:0.0075 Validation Accuracy:0.734200
# Epoch-17,CIFAR-10 Batch-3:  Epoch Loss:0.0054 Validation Accuracy:0.721600
# Epoch-17,CIFAR-10 Batch-4:  Epoch Loss:0.0203 Validation Accuracy:0.735600
# Epoch-17,CIFAR-10 Batch-5:  Epoch Loss:0.0177 Validation Accuracy:0.729400
# Epoch-18,CIFAR-10 Batch-1:  Epoch Loss:0.0291 Validation Accuracy:0.729400
# Epoch-18,CIFAR-10 Batch-2:  Epoch Loss:0.0181 Validation Accuracy:0.740400
# Epoch-18,CIFAR-10 Batch-3:  Epoch Loss:0.0048 Validation Accuracy:0.727200
# Epoch-18,CIFAR-10 Batch-4:  Epoch Loss:0.0227 Validation Accuracy:0.727800
# Epoch-18,CIFAR-10 Batch-5:  Epoch Loss:0.0051 Validation Accuracy:0.728200
# Epoch-19,CIFAR-10 Batch-1:  Epoch Loss:0.0166 Validation Accuracy:0.726400
# Epoch-19,CIFAR-10 Batch-2:  Epoch Loss:0.0096 Validation Accuracy:0.708800
# Epoch-19,CIFAR-10 Batch-3:  Epoch Loss:0.0074 Validation Accuracy:0.737000
# Epoch-19,CIFAR-10 Batch-4:  Epoch Loss:0.0386 Validation Accuracy:0.735400
# Epoch-19,CIFAR-10 Batch-5:  Epoch Loss:0.0212 Validation Accuracy:0.732200
# Epoch-20,CIFAR-10 Batch-1:  Epoch Loss:0.0350 Validation Accuracy:0.723800
# Epoch-20,CIFAR-10 Batch-2:  Epoch Loss:0.0110 Validation Accuracy:0.730000
# Epoch-20,CIFAR-10 Batch-3:  Epoch Loss:0.0019 Validation Accuracy:0.723400
# Epoch-20,CIFAR-10 Batch-4:  Epoch Loss:0.0222 Validation Accuracy:0.721400
# Epoch-20,CIFAR-10 Batch-5:  Epoch Loss:0.0078 Validation Accuracy:0.740200
# Epoch-21,CIFAR-10 Batch-1:  Epoch Loss:0.0143 Validation Accuracy:0.745000
# Epoch-21,CIFAR-10 Batch-2:  Epoch Loss:0.0044 Validation Accuracy:0.737600
# Epoch-21,CIFAR-10 Batch-3:  Epoch Loss:0.0060 Validation Accuracy:0.728600
# Epoch-21,CIFAR-10 Batch-4:  Epoch Loss:0.0090 Validation Accuracy:0.736800
# Epoch-21,CIFAR-10 Batch-5:  Epoch Loss:0.0038 Validation Accuracy:0.735400
# Epoch-22,CIFAR-10 Batch-1:  Epoch Loss:0.0372 Validation Accuracy:0.733000
# Epoch-22,CIFAR-10 Batch-2:  Epoch Loss:0.0041 Validation Accuracy:0.738400
# Epoch-22,CIFAR-10 Batch-3:  Epoch Loss:0.0095 Validation Accuracy:0.729600
# Epoch-22,CIFAR-10 Batch-4:  Epoch Loss:0.0274 Validation Accuracy:0.729400
# Epoch-22,CIFAR-10 Batch-5:  Epoch Loss:0.0433 Validation Accuracy:0.732000
# Epoch-23,CIFAR-10 Batch-1:  Epoch Loss:0.0083 Validation Accuracy:0.734200
# Epoch-23,CIFAR-10 Batch-2:  Epoch Loss:0.0014 Validation Accuracy:0.727000
# Epoch-23,CIFAR-10 Batch-3:  Epoch Loss:0.0137 Validation Accuracy:0.717200
# Epoch-23,CIFAR-10 Batch-4:  Epoch Loss:0.0091 Validation Accuracy:0.740600
# Epoch-23,CIFAR-10 Batch-5:  Epoch Loss:0.0036 Validation Accuracy:0.734000
# Epoch-24,CIFAR-10 Batch-1:  Epoch Loss:0.0206 Validation Accuracy:0.732200
# Epoch-24,CIFAR-10 Batch-2:  Epoch Loss:0.0158 Validation Accuracy:0.720600
# Epoch-24,CIFAR-10 Batch-3:  Epoch Loss:0.0046 Validation Accuracy:0.732600
# Epoch-24,CIFAR-10 Batch-4:  Epoch Loss:0.0041 Validation Accuracy:0.722200
# Epoch-24,CIFAR-10 Batch-5:  Epoch Loss:0.0044 Validation Accuracy:0.731600
# Epoch-25,CIFAR-10 Batch-1:  Epoch Loss:0.0025 Validation Accuracy:0.735400
# Epoch-25,CIFAR-10 Batch-2:  Epoch Loss:0.0097 Validation Accuracy:0.737000
# Epoch-25,CIFAR-10 Batch-3:  Epoch Loss:0.0022 Validation Accuracy:0.734400
# Epoch-25,CIFAR-10 Batch-4:  Epoch Loss:0.0014 Validation Accuracy:0.743600
# Epoch-25,CIFAR-10 Batch-5:  Epoch Loss:0.0152 Validation Accuracy:0.734000
# Epoch-26,CIFAR-10 Batch-1:  Epoch Loss:0.0015 Validation Accuracy:0.738600
# Epoch-26,CIFAR-10 Batch-2:  Epoch Loss:0.0121 Validation Accuracy:0.729800
# Epoch-26,CIFAR-10 Batch-3:  Epoch Loss:0.0107 Validation Accuracy:0.720400
# Epoch-26,CIFAR-10 Batch-4:  Epoch Loss:0.0049 Validation Accuracy:0.734400
# Epoch-26,CIFAR-10 Batch-5:  Epoch Loss:0.0279 Validation Accuracy:0.729000
# Epoch-27,CIFAR-10 Batch-1:  Epoch Loss:0.1131 Validation Accuracy:0.721800
# Epoch-27,CIFAR-10 Batch-2:  Epoch Loss:0.0012 Validation Accuracy:0.719600
# Epoch-27,CIFAR-10 Batch-3:  Epoch Loss:0.0088 Validation Accuracy:0.721200
# Epoch-27,CIFAR-10 Batch-4:  Epoch Loss:0.0018 Validation Accuracy:0.734800
# Epoch-27,CIFAR-10 Batch-5:  Epoch Loss:0.0159 Validation Accuracy:0.741200
# Epoch-28,CIFAR-10 Batch-1:  Epoch Loss:0.0018 Validation Accuracy:0.742200
# Epoch-28,CIFAR-10 Batch-2:  Epoch Loss:0.0007 Validation Accuracy:0.743800
# Epoch-28,CIFAR-10 Batch-3:  Epoch Loss:0.0040 Validation Accuracy:0.738000
# Epoch-28,CIFAR-10 Batch-4:  Epoch Loss:0.0004 Validation Accuracy:0.741800
# Epoch-28,CIFAR-10 Batch-5:  Epoch Loss:0.0007 Validation Accuracy:0.734800
# Epoch-29,CIFAR-10 Batch-1:  Epoch Loss:0.0208 Validation Accuracy:0.729400
# Epoch-29,CIFAR-10 Batch-2:  Epoch Loss:0.0009 Validation Accuracy:0.728600
# Epoch-29,CIFAR-10 Batch-3:  Epoch Loss:0.0200 Validation Accuracy:0.731800
# Epoch-29,CIFAR-10 Batch-4:  Epoch Loss:0.0077 Validation Accuracy:0.732000
# Epoch-29,CIFAR-10 Batch-5:  Epoch Loss:0.0009 Validation Accuracy:0.741400
# Epoch-30,CIFAR-10 Batch-1:  Epoch Loss:0.0019 Validation Accuracy:0.734400
# Epoch-30,CIFAR-10 Batch-2:  Epoch Loss:0.0039 Validation Accuracy:0.731000
# Epoch-30,CIFAR-10 Batch-3:  Epoch Loss:0.0009 Validation Accuracy:0.736800
# Epoch-30,CIFAR-10 Batch-4:  Epoch Loss:0.0008 Validation Accuracy:0.732800
# Epoch-30,CIFAR-10 Batch-5:  Epoch Loss:0.0031 Validation Accuracy:0.732400
# Epoch-31,CIFAR-10 Batch-1:  Epoch Loss:0.0003 Validation Accuracy:0.738800
# Epoch-31,CIFAR-10 Batch-2:  Epoch Loss:0.0004 Validation Accuracy:0.733600
# Epoch-31,CIFAR-10 Batch-3:  Epoch Loss:0.0012 Validation Accuracy:0.719200
# Epoch-31,CIFAR-10 Batch-4:  Epoch Loss:0.0019 Validation Accuracy:0.738600
# Epoch-31,CIFAR-10 Batch-5:  Epoch Loss:0.0026 Validation Accuracy:0.740400
# Epoch-32,CIFAR-10 Batch-1:  Epoch Loss:0.0169 Validation Accuracy:0.733400
# Epoch-32,CIFAR-10 Batch-2:  Epoch Loss:0.0067 Validation Accuracy:0.734400
# Epoch-32,CIFAR-10 Batch-3:  Epoch Loss:0.0040 Validation Accuracy:0.738000
# Epoch-32,CIFAR-10 Batch-4:  Epoch Loss:0.0126 Validation Accuracy:0.731200
# Epoch-32,CIFAR-10 Batch-5:  Epoch Loss:0.0574 Validation Accuracy:0.740400
# Epoch-33,CIFAR-10 Batch-1:  Epoch Loss:0.0235 Validation Accuracy:0.739600
# Epoch-33,CIFAR-10 Batch-2:  Epoch Loss:0.0007 Validation Accuracy:0.734400
# Epoch-33,CIFAR-10 Batch-3:  Epoch Loss:0.0039 Validation Accuracy:0.734800
# Epoch-33,CIFAR-10 Batch-4:  Epoch Loss:0.0103 Validation Accuracy:0.736200
# Epoch-33,CIFAR-10 Batch-5:  Epoch Loss:0.0017 Validation Accuracy:0.736200
# Epoch-34,CIFAR-10 Batch-1:  Epoch Loss:0.0229 Validation Accuracy:0.729000
# Epoch-34,CIFAR-10 Batch-2:  Epoch Loss:0.0004 Validation Accuracy:0.730200
# Epoch-34,CIFAR-10 Batch-3:  Epoch Loss:0.0032 Validation Accuracy:0.740400
# Epoch-34,CIFAR-10 Batch-4:  Epoch Loss:0.0123 Validation Accuracy:0.731600
# Epoch-34,CIFAR-10 Batch-5:  Epoch Loss:0.0029 Validation Accuracy:0.742200
# Epoch-35,CIFAR-10 Batch-1:  Epoch Loss:0.0101 Validation Accuracy:0.735200
# Epoch-35,CIFAR-10 Batch-2:  Epoch Loss:0.0009 Validation Accuracy:0.738800
# Epoch-35,CIFAR-10 Batch-3:  Epoch Loss:0.0009 Validation Accuracy:0.741800
# Epoch-35,CIFAR-10 Batch-4:  Epoch Loss:0.0005 Validation Accuracy:0.743000
# Epoch-35,CIFAR-10 Batch-5:  Epoch Loss:0.0018 Validation Accuracy:0.733400
# Epoch-36,CIFAR-10 Batch-1:  Epoch Loss:0.0305 Validation Accuracy:0.732400
# Epoch-36,CIFAR-10 Batch-2:  Epoch Loss:0.0025 Validation Accuracy:0.740600
# Epoch-36,CIFAR-10 Batch-3:  Epoch Loss:0.0137 Validation Accuracy:0.741200
# Epoch-36,CIFAR-10 Batch-4:  Epoch Loss:0.0059 Validation Accuracy:0.728600
# Epoch-36,CIFAR-10 Batch-5:  Epoch Loss:0.0005 Validation Accuracy:0.732000
# Epoch-37,CIFAR-10 Batch-1:  Epoch Loss:0.0045 Validation Accuracy:0.731800
# Epoch-37,CIFAR-10 Batch-2:  Epoch Loss:0.0005 Validation Accuracy:0.731400
# Epoch-37,CIFAR-10 Batch-3:  Epoch Loss:0.0032 Validation Accuracy:0.736400
# Epoch-37,CIFAR-10 Batch-4:  Epoch Loss:0.0039 Validation Accuracy:0.735000
# Epoch-37,CIFAR-10 Batch-5:  Epoch Loss:0.0008 Validation Accuracy:0.732400
# Epoch-38,CIFAR-10 Batch-1:  Epoch Loss:0.0012 Validation Accuracy:0.743200
# Epoch-38,CIFAR-10 Batch-2:  Epoch Loss:0.0005 Validation Accuracy:0.736200
# Epoch-38,CIFAR-10 Batch-3:  Epoch Loss:0.0037 Validation Accuracy:0.739400
# Epoch-38,CIFAR-10 Batch-4:  Epoch Loss:0.0023 Validation Accuracy:0.736000
# Epoch-38,CIFAR-10 Batch-5:  Epoch Loss:0.0047 Validation Accuracy:0.742000
# Epoch-39,CIFAR-10 Batch-1:  Epoch Loss:0.0049 Validation Accuracy:0.736200
# Epoch-39,CIFAR-10 Batch-2:  Epoch Loss:0.0019 Validation Accuracy:0.742400
# Epoch-39,CIFAR-10 Batch-3:  Epoch Loss:0.0155 Validation Accuracy:0.730600
# Epoch-39,CIFAR-10 Batch-4:  Epoch Loss:0.0010 Validation Accuracy:0.728000
# Epoch-39,CIFAR-10 Batch-5:  Epoch Loss:0.0035 Validation Accuracy:0.744800
# Epoch-40,CIFAR-10 Batch-1:  Epoch Loss:0.0027 Validation Accuracy:0.740600
# Epoch-40,CIFAR-10 Batch-2:  Epoch Loss:0.0034 Validation Accuracy:0.734400
# Epoch-40,CIFAR-10 Batch-3:  Epoch Loss:0.0261 Validation Accuracy:0.739200
# Epoch-40,CIFAR-10 Batch-4:  Epoch Loss:0.0003 Validation Accuracy:0.739200
# Epoch-40,CIFAR-10 Batch-5:  Epoch Loss:0.0005 Validation Accuracy:0.745600
# Epoch-41,CIFAR-10 Batch-1:  Epoch Loss:0.0044 Validation Accuracy:0.730200
# Epoch-41,CIFAR-10 Batch-2:  Epoch Loss:0.0007 Validation Accuracy:0.736200
# Epoch-41,CIFAR-10 Batch-3:  Epoch Loss:0.0183 Validation Accuracy:0.750800
# Epoch-41,CIFAR-10 Batch-4:  Epoch Loss:0.0008 Validation Accuracy:0.723000
# Epoch-41,CIFAR-10 Batch-5:  Epoch Loss:0.0049 Validation Accuracy:0.737600
# Epoch-42,CIFAR-10 Batch-1:  Epoch Loss:0.0135 Validation Accuracy:0.738200
# Epoch-42,CIFAR-10 Batch-2:  Epoch Loss:0.0091 Validation Accuracy:0.741800
# Epoch-42,CIFAR-10 Batch-3:  Epoch Loss:0.0096 Validation Accuracy:0.737400
# Epoch-42,CIFAR-10 Batch-4:  Epoch Loss:0.0024 Validation Accuracy:0.742600
# Epoch-42,CIFAR-10 Batch-5:  Epoch Loss:0.0048 Validation Accuracy:0.724600
# Epoch-43,CIFAR-10 Batch-1:  Epoch Loss:0.0217 Validation Accuracy:0.745600
# Epoch-43,CIFAR-10 Batch-2:  Epoch Loss:0.0015 Validation Accuracy:0.730600
# Epoch-43,CIFAR-10 Batch-3:  Epoch Loss:0.0006 Validation Accuracy:0.739200
# Epoch-43,CIFAR-10 Batch-4:  Epoch Loss:0.0009 Validation Accuracy:0.730200
# Epoch-43,CIFAR-10 Batch-5:  Epoch Loss:0.0014 Validation Accuracy:0.740200
# Epoch-44,CIFAR-10 Batch-1:  Epoch Loss:0.0667 Validation Accuracy:0.726400
# Epoch-44,CIFAR-10 Batch-2:  Epoch Loss:0.0015 Validation Accuracy:0.733800
# Epoch-44,CIFAR-10 Batch-3:  Epoch Loss:0.0006 Validation Accuracy:0.740800
# Epoch-44,CIFAR-10 Batch-4:  Epoch Loss:0.0011 Validation Accuracy:0.734600
# Epoch-44,CIFAR-10 Batch-5:  Epoch Loss:0.0002 Validation Accuracy:0.736000
# Epoch-45,CIFAR-10 Batch-1:  Epoch Loss:0.0010 Validation Accuracy:0.746400
# Epoch-45,CIFAR-10 Batch-2:  Epoch Loss:0.0073 Validation Accuracy:0.726200
# Epoch-45,CIFAR-10 Batch-3:  Epoch Loss:0.0037 Validation Accuracy:0.741200
# Epoch-45,CIFAR-10 Batch-4:  Epoch Loss:0.0304 Validation Accuracy:0.731200
# Epoch-45,CIFAR-10 Batch-5:  Epoch Loss:0.0293 Validation Accuracy:0.731800
# Epoch-46,CIFAR-10 Batch-1:  Epoch Loss:0.0005 Validation Accuracy:0.731400
# Epoch-46,CIFAR-10 Batch-2:  Epoch Loss:0.0357 Validation Accuracy:0.726800
# Epoch-46,CIFAR-10 Batch-3:  Epoch Loss:0.0010 Validation Accuracy:0.733600
# Epoch-46,CIFAR-10 Batch-4:  Epoch Loss:0.0225 Validation Accuracy:0.728000
# Epoch-46,CIFAR-10 Batch-5:  Epoch Loss:0.0007 Validation Accuracy:0.733000
# Epoch-47,CIFAR-10 Batch-1:  Epoch Loss:0.0033 Validation Accuracy:0.740400
# Epoch-47,CIFAR-10 Batch-2:  Epoch Loss:0.0016 Validation Accuracy:0.725200
# Epoch-47,CIFAR-10 Batch-3:  Epoch Loss:0.0061 Validation Accuracy:0.722000
# Epoch-47,CIFAR-10 Batch-4:  Epoch Loss:0.0020 Validation Accuracy:0.730600
# Epoch-47,CIFAR-10 Batch-5:  Epoch Loss:0.0053 Validation Accuracy:0.742400
# Epoch-48,CIFAR-10 Batch-1:  Epoch Loss:0.0016 Validation Accuracy:0.743400
# Epoch-48,CIFAR-10 Batch-2:  Epoch Loss:0.0012 Validation Accuracy:0.730000
# Epoch-48,CIFAR-10 Batch-3:  Epoch Loss:0.0003 Validation Accuracy:0.746400
# Epoch-48,CIFAR-10 Batch-4:  Epoch Loss:0.0070 Validation Accuracy:0.731000
# Epoch-48,CIFAR-10 Batch-5:  Epoch Loss:0.0079 Validation Accuracy:0.734800
# Epoch-49,CIFAR-10 Batch-1:  Epoch Loss:0.0105 Validation Accuracy:0.742600
# Epoch-49,CIFAR-10 Batch-2:  Epoch Loss:0.0014 Validation Accuracy:0.736600
# Epoch-49,CIFAR-10 Batch-3:  Epoch Loss:0.0018 Validation Accuracy:0.738200
# Epoch-49,CIFAR-10 Batch-4:  Epoch Loss:0.0136 Validation Accuracy:0.730400
# Epoch-49,CIFAR-10 Batch-5:  Epoch Loss:0.0134 Validation Accuracy:0.739200
# Epoch-50,CIFAR-10 Batch-1:  Epoch Loss:0.0073 Validation Accuracy:0.743200
# Epoch-50,CIFAR-10 Batch-2:  Epoch Loss:0.0007 Validation Accuracy:0.739800
# Epoch-50,CIFAR-10 Batch-3:  Epoch Loss:0.0041 Validation Accuracy:0.739800
# Epoch-50,CIFAR-10 Batch-4:  Epoch Loss:0.0149 Validation Accuracy:0.736800
# Epoch-50,CIFAR-10 Batch-5:  Epoch Loss:0.0000 Validation Accuracy:0.744600
# Epoch-51,CIFAR-10 Batch-1:  Epoch Loss:0.0023 Validation Accuracy:0.736800
# Epoch-51,CIFAR-10 Batch-2:  Epoch Loss:0.0066 Validation Accuracy:0.727400
# Epoch-51,CIFAR-10 Batch-3:  Epoch Loss:0.0020 Validation Accuracy:0.745800
# Epoch-51,CIFAR-10 Batch-4:  Epoch Loss:0.0181 Validation Accuracy:0.735600
# Epoch-51,CIFAR-10 Batch-5:  Epoch Loss:0.0021 Validation Accuracy:0.747200
# Epoch-52,CIFAR-10 Batch-1:  Epoch Loss:0.0008 Validation Accuracy:0.742600
# Epoch-52,CIFAR-10 Batch-2:  Epoch Loss:0.0001 Validation Accuracy:0.737800
# Epoch-52,CIFAR-10 Batch-3:  Epoch Loss:0.0050 Validation Accuracy:0.744400
# Epoch-52,CIFAR-10 Batch-4:  Epoch Loss:0.0002 Validation Accuracy:0.745800
# Epoch-52,CIFAR-10 Batch-5:  Epoch Loss:0.0070 Validation Accuracy:0.739200
# Epoch-53,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.733200
# Epoch-53,CIFAR-10 Batch-2:  Epoch Loss:0.0002 Validation Accuracy:0.736400
# Epoch-53,CIFAR-10 Batch-3:  Epoch Loss:0.0015 Validation Accuracy:0.743000
# Epoch-53,CIFAR-10 Batch-4:  Epoch Loss:0.0059 Validation Accuracy:0.743200
# Epoch-53,CIFAR-10 Batch-5:  Epoch Loss:0.0011 Validation Accuracy:0.746800
# Epoch-54,CIFAR-10 Batch-1:  Epoch Loss:0.0009 Validation Accuracy:0.731800
# Epoch-54,CIFAR-10 Batch-2:  Epoch Loss:0.0001 Validation Accuracy:0.738800
# Epoch-54,CIFAR-10 Batch-3:  Epoch Loss:0.0003 Validation Accuracy:0.739800
# Epoch-54,CIFAR-10 Batch-4:  Epoch Loss:0.0009 Validation Accuracy:0.735200
# Epoch-54,CIFAR-10 Batch-5:  Epoch Loss:0.0001 Validation Accuracy:0.738800
# Epoch-55,CIFAR-10 Batch-1:  Epoch Loss:0.0041 Validation Accuracy:0.742400
# Epoch-55,CIFAR-10 Batch-2:  Epoch Loss:0.0000 Validation Accuracy:0.740600
# Epoch-55,CIFAR-10 Batch-3:  Epoch Loss:0.0000 Validation Accuracy:0.748400
# Epoch-55,CIFAR-10 Batch-4:  Epoch Loss:0.0001 Validation Accuracy:0.745800
# Epoch-55,CIFAR-10 Batch-5:  Epoch Loss:0.0004 Validation Accuracy:0.740600
# Epoch-56,CIFAR-10 Batch-1:  Epoch Loss:0.0022 Validation Accuracy:0.732600
# Epoch-56,CIFAR-10 Batch-2:  Epoch Loss:0.0022 Validation Accuracy:0.725800
# Epoch-56,CIFAR-10 Batch-3:  Epoch Loss:0.0011 Validation Accuracy:0.739800
# Epoch-56,CIFAR-10 Batch-4:  Epoch Loss:0.0004 Validation Accuracy:0.736200
# Epoch-56,CIFAR-10 Batch-5:  Epoch Loss:0.0009 Validation Accuracy:0.732400
# Epoch-57,CIFAR-10 Batch-1:  Epoch Loss:0.0007 Validation Accuracy:0.743000
# Epoch-57,CIFAR-10 Batch-2:  Epoch Loss:0.0002 Validation Accuracy:0.727600
# Epoch-57,CIFAR-10 Batch-3:  Epoch Loss:0.0003 Validation Accuracy:0.748600
# Epoch-57,CIFAR-10 Batch-4:  Epoch Loss:0.0004 Validation Accuracy:0.738800
# Epoch-57,CIFAR-10 Batch-5:  Epoch Loss:0.0053 Validation Accuracy:0.742800
# Epoch-58,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.743000
# Epoch-58,CIFAR-10 Batch-2:  Epoch Loss:0.0002 Validation Accuracy:0.741200
# Epoch-58,CIFAR-10 Batch-3:  Epoch Loss:0.0002 Validation Accuracy:0.747200
# Epoch-58,CIFAR-10 Batch-4:  Epoch Loss:0.0004 Validation Accuracy:0.735600
# Epoch-58,CIFAR-10 Batch-5:  Epoch Loss:0.0007 Validation Accuracy:0.740400
# Epoch-59,CIFAR-10 Batch-1:  Epoch Loss:0.0005 Validation Accuracy:0.746800
# Epoch-59,CIFAR-10 Batch-2:  Epoch Loss:0.0000 Validation Accuracy:0.749800
# Epoch-59,CIFAR-10 Batch-3:  Epoch Loss:0.0003 Validation Accuracy:0.743400
# Epoch-59,CIFAR-10 Batch-4:  Epoch Loss:0.0001 Validation Accuracy:0.740000
# Epoch-59,CIFAR-10 Batch-5:  Epoch Loss:0.0066 Validation Accuracy:0.735200
# Epoch-60,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.736000
# Epoch-60,CIFAR-10 Batch-2:  Epoch Loss:0.0005 Validation Accuracy:0.722600
# Epoch-60,CIFAR-10 Batch-3:  Epoch Loss:0.0055 Validation Accuracy:0.732600
# Epoch-60,CIFAR-10 Batch-4:  Epoch Loss:0.0029 Validation Accuracy:0.739000
# Epoch-60,CIFAR-10 Batch-5:  Epoch Loss:0.0007 Validation Accuracy:0.725800
# Epoch-61,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.745600
# Epoch-61,CIFAR-10 Batch-2:  Epoch Loss:0.0001 Validation Accuracy:0.736400
# Epoch-61,CIFAR-10 Batch-3:  Epoch Loss:0.0002 Validation Accuracy:0.736200
# Epoch-61,CIFAR-10 Batch-4:  Epoch Loss:0.0003 Validation Accuracy:0.729800
# Epoch-61,CIFAR-10 Batch-5:  Epoch Loss:0.0004 Validation Accuracy:0.736600
# Epoch-62,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.732400
# Epoch-62,CIFAR-10 Batch-2:  Epoch Loss:0.0002 Validation Accuracy:0.744600
# Epoch-62,CIFAR-10 Batch-3:  Epoch Loss:0.0018 Validation Accuracy:0.740200
# Epoch-62,CIFAR-10 Batch-4:  Epoch Loss:0.0019 Validation Accuracy:0.739400
# Epoch-62,CIFAR-10 Batch-5:  Epoch Loss:0.0000 Validation Accuracy:0.742200
# Epoch-63,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.741000
# Epoch-63,CIFAR-10 Batch-2:  Epoch Loss:0.0002 Validation Accuracy:0.741600
# Epoch-63,CIFAR-10 Batch-3:  Epoch Loss:0.0207 Validation Accuracy:0.730200
# Epoch-63,CIFAR-10 Batch-4:  Epoch Loss:0.0062 Validation Accuracy:0.728600
# Epoch-63,CIFAR-10 Batch-5:  Epoch Loss:0.0002 Validation Accuracy:0.726200
# Epoch-64,CIFAR-10 Batch-1:  Epoch Loss:0.0005 Validation Accuracy:0.741800
# Epoch-64,CIFAR-10 Batch-2:  Epoch Loss:0.0008 Validation Accuracy:0.742200
# Epoch-64,CIFAR-10 Batch-3:  Epoch Loss:0.0001 Validation Accuracy:0.745600
# Epoch-64,CIFAR-10 Batch-4:  Epoch Loss:0.0012 Validation Accuracy:0.751000
# Epoch-64,CIFAR-10 Batch-5:  Epoch Loss:0.0032 Validation Accuracy:0.737600
# Epoch-65,CIFAR-10 Batch-1:  Epoch Loss:0.0092 Validation Accuracy:0.743000
# Epoch-65,CIFAR-10 Batch-2:  Epoch Loss:0.0027 Validation Accuracy:0.743200
# Epoch-65,CIFAR-10 Batch-3:  Epoch Loss:0.0041 Validation Accuracy:0.742200
# Epoch-65,CIFAR-10 Batch-4:  Epoch Loss:0.0002 Validation Accuracy:0.742200
# Epoch-65,CIFAR-10 Batch-5:  Epoch Loss:0.0004 Validation Accuracy:0.745200
# Epoch-66,CIFAR-10 Batch-1:  Epoch Loss:0.0016 Validation Accuracy:0.737000
# Epoch-66,CIFAR-10 Batch-2:  Epoch Loss:0.0001 Validation Accuracy:0.739600
# Epoch-66,CIFAR-10 Batch-3:  Epoch Loss:0.0003 Validation Accuracy:0.742200
# Epoch-66,CIFAR-10 Batch-4:  Epoch Loss:0.0063 Validation Accuracy:0.736200
# Epoch-66,CIFAR-10 Batch-5:  Epoch Loss:0.0002 Validation Accuracy:0.737000
# Epoch-67,CIFAR-10 Batch-1:  Epoch Loss:0.0154 Validation Accuracy:0.722200
# Epoch-67,CIFAR-10 Batch-2:  Epoch Loss:0.0001 Validation Accuracy:0.738800
# Epoch-67,CIFAR-10 Batch-3:  Epoch Loss:0.0007 Validation Accuracy:0.733200
# Epoch-67,CIFAR-10 Batch-4:  Epoch Loss:0.0033 Validation Accuracy:0.742200
# Epoch-67,CIFAR-10 Batch-5:  Epoch Loss:0.0007 Validation Accuracy:0.736200
# Epoch-68,CIFAR-10 Batch-1:  Epoch Loss:0.0024 Validation Accuracy:0.739200
# Epoch-68,CIFAR-10 Batch-2:  Epoch Loss:0.0002 Validation Accuracy:0.736800
# Epoch-68,CIFAR-10 Batch-3:  Epoch Loss:0.0011 Validation Accuracy:0.741400
# Epoch-68,CIFAR-10 Batch-4:  Epoch Loss:0.0014 Validation Accuracy:0.730000
# Epoch-68,CIFAR-10 Batch-5:  Epoch Loss:0.0007 Validation Accuracy:0.752400
# Epoch-69,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.738600
# Epoch-69,CIFAR-10 Batch-2:  Epoch Loss:0.0005 Validation Accuracy:0.740600
# Epoch-69,CIFAR-10 Batch-3:  Epoch Loss:0.0000 Validation Accuracy:0.743000
# Epoch-69,CIFAR-10 Batch-4:  Epoch Loss:0.0214 Validation Accuracy:0.728600
# Epoch-69,CIFAR-10 Batch-5:  Epoch Loss:0.0049 Validation Accuracy:0.741400
# Epoch-70,CIFAR-10 Batch-1:  Epoch Loss:0.0038 Validation Accuracy:0.736800
# Epoch-70,CIFAR-10 Batch-2:  Epoch Loss:0.0011 Validation Accuracy:0.733200
# Epoch-70,CIFAR-10 Batch-3:  Epoch Loss:0.0079 Validation Accuracy:0.747000
# Epoch-70,CIFAR-10 Batch-4:  Epoch Loss:0.0082 Validation Accuracy:0.735600
# Epoch-70,CIFAR-10 Batch-5:  Epoch Loss:0.0005 Validation Accuracy:0.740000
# Epoch-71,CIFAR-10 Batch-1:  Epoch Loss:0.0009 Validation Accuracy:0.740600
# Epoch-71,CIFAR-10 Batch-2:  Epoch Loss:0.0002 Validation Accuracy:0.737800
# Epoch-71,CIFAR-10 Batch-3:  Epoch Loss:0.0001 Validation Accuracy:0.742000
# Epoch-71,CIFAR-10 Batch-4:  Epoch Loss:0.0006 Validation Accuracy:0.722000
# Epoch-71,CIFAR-10 Batch-5:  Epoch Loss:0.0117 Validation Accuracy:0.740200
# Epoch-72,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.741400
# Epoch-72,CIFAR-10 Batch-2:  Epoch Loss:0.0029 Validation Accuracy:0.740600
# Epoch-72,CIFAR-10 Batch-3:  Epoch Loss:0.0006 Validation Accuracy:0.742000
# Epoch-72,CIFAR-10 Batch-4:  Epoch Loss:0.0004 Validation Accuracy:0.728400
# Epoch-72,CIFAR-10 Batch-5:  Epoch Loss:0.0001 Validation Accuracy:0.745600
# Epoch-73,CIFAR-10 Batch-1:  Epoch Loss:0.0021 Validation Accuracy:0.738000
# Epoch-73,CIFAR-10 Batch-2:  Epoch Loss:0.0007 Validation Accuracy:0.738800
# Epoch-73,CIFAR-10 Batch-3:  Epoch Loss:0.0069 Validation Accuracy:0.729800
# Epoch-73,CIFAR-10 Batch-4:  Epoch Loss:0.0009 Validation Accuracy:0.724800
# Epoch-73,CIFAR-10 Batch-5:  Epoch Loss:0.0029 Validation Accuracy:0.735200
# Epoch-74,CIFAR-10 Batch-1:  Epoch Loss:0.0010 Validation Accuracy:0.735400
# Epoch-74,CIFAR-10 Batch-2:  Epoch Loss:0.0004 Validation Accuracy:0.745400
# Epoch-74,CIFAR-10 Batch-3:  Epoch Loss:0.0001 Validation Accuracy:0.746000
# Epoch-74,CIFAR-10 Batch-4:  Epoch Loss:0.0005 Validation Accuracy:0.740600
# Epoch-74,CIFAR-10 Batch-5:  Epoch Loss:0.0002 Validation Accuracy:0.751200
# Epoch-75,CIFAR-10 Batch-1:  Epoch Loss:0.0003 Validation Accuracy:0.745400
# Epoch-75,CIFAR-10 Batch-2:  Epoch Loss:0.0043 Validation Accuracy:0.742200
# Epoch-75,CIFAR-10 Batch-3:  Epoch Loss:0.0001 Validation Accuracy:0.739600
# Epoch-75,CIFAR-10 Batch-4:  Epoch Loss:0.0003 Validation Accuracy:0.744400
# Epoch-75,CIFAR-10 Batch-5:  Epoch Loss:0.0034 Validation Accuracy:0.743400
# Epoch-76,CIFAR-10 Batch-1:  Epoch Loss:0.0009 Validation Accuracy:0.733400
# Epoch-76,CIFAR-10 Batch-2:  Epoch Loss:0.0005 Validation Accuracy:0.734000
# Epoch-76,CIFAR-10 Batch-3:  Epoch Loss:0.0009 Validation Accuracy:0.748800
# Epoch-76,CIFAR-10 Batch-4:  Epoch Loss:0.0017 Validation Accuracy:0.739800
# Epoch-76,CIFAR-10 Batch-5:  Epoch Loss:0.0002 Validation Accuracy:0.735600
# Epoch-77,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.738000
# Epoch-77,CIFAR-10 Batch-2:  Epoch Loss:0.0019 Validation Accuracy:0.746000
# Epoch-77,CIFAR-10 Batch-3:  Epoch Loss:0.0013 Validation Accuracy:0.740200
# Epoch-77,CIFAR-10 Batch-4:  Epoch Loss:0.0020 Validation Accuracy:0.742800
# Epoch-77,CIFAR-10 Batch-5:  Epoch Loss:0.0001 Validation Accuracy:0.747800
# Epoch-78,CIFAR-10 Batch-1:  Epoch Loss:0.0036 Validation Accuracy:0.722400
# Epoch-78,CIFAR-10 Batch-2:  Epoch Loss:0.0007 Validation Accuracy:0.749000
# Epoch-78,CIFAR-10 Batch-3:  Epoch Loss:0.0055 Validation Accuracy:0.747400
# Epoch-78,CIFAR-10 Batch-4:  Epoch Loss:0.0143 Validation Accuracy:0.736800
# Epoch-78,CIFAR-10 Batch-5:  Epoch Loss:0.0012 Validation Accuracy:0.754400
# Epoch-79,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.739000
# Epoch-79,CIFAR-10 Batch-2:  Epoch Loss:0.0090 Validation Accuracy:0.739600
# Epoch-79,CIFAR-10 Batch-3:  Epoch Loss:0.0199 Validation Accuracy:0.749000
# Epoch-79,CIFAR-10 Batch-4:  Epoch Loss:0.0000 Validation Accuracy:0.751200
# Epoch-79,CIFAR-10 Batch-5:  Epoch Loss:0.0000 Validation Accuracy:0.747400
# Epoch-80,CIFAR-10 Batch-1:  Epoch Loss:0.0015 Validation Accuracy:0.739200
# Epoch-80,CIFAR-10 Batch-2:  Epoch Loss:0.0002 Validation Accuracy:0.744800
# Epoch-80,CIFAR-10 Batch-3:  Epoch Loss:0.0043 Validation Accuracy:0.742600
# Epoch-80,CIFAR-10 Batch-4:  Epoch Loss:0.0003 Validation Accuracy:0.740000
# Epoch-80,CIFAR-10 Batch-5:  Epoch Loss:0.0025 Validation Accuracy:0.748800
# Epoch-81,CIFAR-10 Batch-1:  Epoch Loss:0.0097 Validation Accuracy:0.746800
# Epoch-81,CIFAR-10 Batch-2:  Epoch Loss:0.0005 Validation Accuracy:0.750600
# Epoch-81,CIFAR-10 Batch-3:  Epoch Loss:0.0001 Validation Accuracy:0.746600
# Epoch-81,CIFAR-10 Batch-4:  Epoch Loss:0.0001 Validation Accuracy:0.744400
# Epoch-81,CIFAR-10 Batch-5:  Epoch Loss:0.0010 Validation Accuracy:0.747200
# Epoch-82,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.743000
# Epoch-82,CIFAR-10 Batch-2:  Epoch Loss:0.0001 Validation Accuracy:0.749600
# Epoch-82,CIFAR-10 Batch-3:  Epoch Loss:0.0014 Validation Accuracy:0.744200
# Epoch-82,CIFAR-10 Batch-4:  Epoch Loss:0.0001 Validation Accuracy:0.739800
# Epoch-82,CIFAR-10 Batch-5:  Epoch Loss:0.0039 Validation Accuracy:0.745600
# Epoch-83,CIFAR-10 Batch-1:  Epoch Loss:0.0016 Validation Accuracy:0.745400
# Epoch-83,CIFAR-10 Batch-2:  Epoch Loss:0.0009 Validation Accuracy:0.746800
# Epoch-83,CIFAR-10 Batch-3:  Epoch Loss:0.0001 Validation Accuracy:0.739600
# Epoch-83,CIFAR-10 Batch-4:  Epoch Loss:0.0003 Validation Accuracy:0.741800
# Epoch-83,CIFAR-10 Batch-5:  Epoch Loss:0.0000 Validation Accuracy:0.749200
# Epoch-84,CIFAR-10 Batch-1:  Epoch Loss:0.0005 Validation Accuracy:0.737800
# Epoch-84,CIFAR-10 Batch-2:  Epoch Loss:0.0004 Validation Accuracy:0.748000
# Epoch-84,CIFAR-10 Batch-3:  Epoch Loss:0.0011 Validation Accuracy:0.741000
# Epoch-84,CIFAR-10 Batch-4:  Epoch Loss:0.0000 Validation Accuracy:0.734200
# Epoch-84,CIFAR-10 Batch-5:  Epoch Loss:0.0013 Validation Accuracy:0.743000
# Epoch-85,CIFAR-10 Batch-1:  Epoch Loss:0.0017 Validation Accuracy:0.747400
# Epoch-85,CIFAR-10 Batch-2:  Epoch Loss:0.0103 Validation Accuracy:0.744400
# Epoch-85,CIFAR-10 Batch-3:  Epoch Loss:0.0001 Validation Accuracy:0.748600
# Epoch-85,CIFAR-10 Batch-4:  Epoch Loss:0.0001 Validation Accuracy:0.741400
# Epoch-85,CIFAR-10 Batch-5:  Epoch Loss:0.0001 Validation Accuracy:0.755200
# Epoch-86,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.741400
# Epoch-86,CIFAR-10 Batch-2:  Epoch Loss:0.0001 Validation Accuracy:0.748200
# Epoch-86,CIFAR-10 Batch-3:  Epoch Loss:0.0005 Validation Accuracy:0.747000
# Epoch-86,CIFAR-10 Batch-4:  Epoch Loss:0.0000 Validation Accuracy:0.742800
# Epoch-86,CIFAR-10 Batch-5:  Epoch Loss:0.0000 Validation Accuracy:0.749600
# Epoch-87,CIFAR-10 Batch-1:  Epoch Loss:0.0026 Validation Accuracy:0.735000
# Epoch-87,CIFAR-10 Batch-2:  Epoch Loss:0.0545 Validation Accuracy:0.744200
# Epoch-87,CIFAR-10 Batch-3:  Epoch Loss:0.0098 Validation Accuracy:0.737000
# Epoch-87,CIFAR-10 Batch-4:  Epoch Loss:0.0002 Validation Accuracy:0.726800
# Epoch-87,CIFAR-10 Batch-5:  Epoch Loss:0.0010 Validation Accuracy:0.745000
# Epoch-88,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.745800
# Epoch-88,CIFAR-10 Batch-2:  Epoch Loss:0.0001 Validation Accuracy:0.750400
# Epoch-88,CIFAR-10 Batch-3:  Epoch Loss:0.0023 Validation Accuracy:0.742200
# Epoch-88,CIFAR-10 Batch-4:  Epoch Loss:0.0000 Validation Accuracy:0.743800
# Epoch-88,CIFAR-10 Batch-5:  Epoch Loss:0.0007 Validation Accuracy:0.749400
# Epoch-89,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.743400
# Epoch-89,CIFAR-10 Batch-2:  Epoch Loss:0.0082 Validation Accuracy:0.733200
# Epoch-89,CIFAR-10 Batch-3:  Epoch Loss:0.0015 Validation Accuracy:0.746200
# Epoch-89,CIFAR-10 Batch-4:  Epoch Loss:0.0002 Validation Accuracy:0.746000
# Epoch-89,CIFAR-10 Batch-5:  Epoch Loss:0.0060 Validation Accuracy:0.744800
# Epoch-90,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.742200
# Epoch-90,CIFAR-10 Batch-2:  Epoch Loss:0.0004 Validation Accuracy:0.745600
# Epoch-90,CIFAR-10 Batch-3:  Epoch Loss:0.0005 Validation Accuracy:0.745000
# Epoch-90,CIFAR-10 Batch-4:  Epoch Loss:0.0001 Validation Accuracy:0.745400
# Epoch-90,CIFAR-10 Batch-5:  Epoch Loss:0.0002 Validation Accuracy:0.746200
# Epoch-91,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.747600
# Epoch-91,CIFAR-10 Batch-2:  Epoch Loss:0.0012 Validation Accuracy:0.751400
# Epoch-91,CIFAR-10 Batch-3:  Epoch Loss:0.0030 Validation Accuracy:0.739600
# Epoch-91,CIFAR-10 Batch-4:  Epoch Loss:0.0005 Validation Accuracy:0.742400
# Epoch-91,CIFAR-10 Batch-5:  Epoch Loss:0.0005 Validation Accuracy:0.747000
# Epoch-92,CIFAR-10 Batch-1:  Epoch Loss:0.0435 Validation Accuracy:0.738000
# Epoch-92,CIFAR-10 Batch-2:  Epoch Loss:0.0005 Validation Accuracy:0.751200
# Epoch-92,CIFAR-10 Batch-3:  Epoch Loss:0.0018 Validation Accuracy:0.748600
# Epoch-92,CIFAR-10 Batch-4:  Epoch Loss:0.0000 Validation Accuracy:0.746600
# Epoch-92,CIFAR-10 Batch-5:  Epoch Loss:0.0107 Validation Accuracy:0.735400
# Epoch-93,CIFAR-10 Batch-1:  Epoch Loss:0.0004 Validation Accuracy:0.738800
# Epoch-93,CIFAR-10 Batch-2:  Epoch Loss:0.0000 Validation Accuracy:0.747800
# Epoch-93,CIFAR-10 Batch-3:  Epoch Loss:0.0000 Validation Accuracy:0.739000
# Epoch-93,CIFAR-10 Batch-4:  Epoch Loss:0.0000 Validation Accuracy:0.736400
# Epoch-93,CIFAR-10 Batch-5:  Epoch Loss:0.0001 Validation Accuracy:0.741400
# Epoch-94,CIFAR-10 Batch-1:  Epoch Loss:0.0003 Validation Accuracy:0.739800
# Epoch-94,CIFAR-10 Batch-2:  Epoch Loss:0.0041 Validation Accuracy:0.734200
# Epoch-94,CIFAR-10 Batch-3:  Epoch Loss:0.0000 Validation Accuracy:0.748000
# Epoch-94,CIFAR-10 Batch-4:  Epoch Loss:0.0017 Validation Accuracy:0.746400
# Epoch-94,CIFAR-10 Batch-5:  Epoch Loss:0.0000 Validation Accuracy:0.748600
# Epoch-95,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.746000
# Epoch-95,CIFAR-10 Batch-2:  Epoch Loss:0.0088 Validation Accuracy:0.745000
# Epoch-95,CIFAR-10 Batch-3:  Epoch Loss:0.0001 Validation Accuracy:0.744000
# Epoch-95,CIFAR-10 Batch-4:  Epoch Loss:0.0012 Validation Accuracy:0.741200
# Epoch-95,CIFAR-10 Batch-5:  Epoch Loss:0.0082 Validation Accuracy:0.739800
# Epoch-96,CIFAR-10 Batch-1:  Epoch Loss:0.0009 Validation Accuracy:0.748600
# Epoch-96,CIFAR-10 Batch-2:  Epoch Loss:0.0021 Validation Accuracy:0.741800
# Epoch-96,CIFAR-10 Batch-3:  Epoch Loss:0.0001 Validation Accuracy:0.747400
# Epoch-96,CIFAR-10 Batch-4:  Epoch Loss:0.0030 Validation Accuracy:0.737600
# Epoch-96,CIFAR-10 Batch-5:  Epoch Loss:0.0000 Validation Accuracy:0.741600
# Epoch-97,CIFAR-10 Batch-1:  Epoch Loss:0.0002 Validation Accuracy:0.738800
# Epoch-97,CIFAR-10 Batch-2:  Epoch Loss:0.0003 Validation Accuracy:0.751000
# Epoch-97,CIFAR-10 Batch-3:  Epoch Loss:0.0000 Validation Accuracy:0.750000
# Epoch-97,CIFAR-10 Batch-4:  Epoch Loss:0.0001 Validation Accuracy:0.752800
# Epoch-97,CIFAR-10 Batch-5:  Epoch Loss:0.0015 Validation Accuracy:0.747000
# Epoch-98,CIFAR-10 Batch-1:  Epoch Loss:0.0000 Validation Accuracy:0.738000
# Epoch-98,CIFAR-10 Batch-2:  Epoch Loss:0.0003 Validation Accuracy:0.748800
# Epoch-98,CIFAR-10 Batch-3:  Epoch Loss:0.0000 Validation Accuracy:0.744400
# Epoch-98,CIFAR-10 Batch-4:  Epoch Loss:0.0000 Validation Accuracy:0.738600
# Epoch-98,CIFAR-10 Batch-5:  Epoch Loss:0.0001 Validation Accuracy:0.746000
# Epoch-99,CIFAR-10 Batch-1:  Epoch Loss:0.0001 Validation Accuracy:0.741400
# Epoch-99,CIFAR-10 Batch-2:  Epoch Loss:0.0008 Validation Accuracy:0.744800
# Epoch-99,CIFAR-10 Batch-3:  Epoch Loss:0.0002 Validation Accuracy:0.742800
# Epoch-99,CIFAR-10 Batch-4:  Epoch Loss:0.0015 Validation Accuracy:0.740800
# Epoch-99,CIFAR-10 Batch-5:  Epoch Loss:0.0001 Validation Accuracy:0.750600
# Epoch-100,CIFAR-10 Batch-1:  Epoch Loss:0.0011 Validation Accuracy:0.747800
# Epoch-100,CIFAR-10 Batch-2:  Epoch Loss:0.0045 Validation Accuracy:0.723600
# Epoch-100,CIFAR-10 Batch-3:  Epoch Loss:0.0002 Validation Accuracy:0.736000
# Epoch-100,CIFAR-10 Batch-4:  Epoch Loss:0.0000 Validation Accuracy:0.749400
# Epoch-100,CIFAR-10 Batch-5:  Epoch Loss:0.0006 Validation Accuracy:0.739400

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7376592356687898

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
